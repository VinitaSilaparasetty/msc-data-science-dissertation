# %% [markdown]
# # EDA for Skincancer detection

# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/skincancer_mnist_ham/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  ...  pixel2350  pixel2351  label
# 0        192        153        193  ...        154        177      2
# 1         25         14         30  ...         14         27      2
# 2        192        138        153  ...        104        117      2
# 3         38         19         30  ...         12         15      2
# 4        158        113        139  ...         78         92      2
#
# [5 rows x 2353 columns]

# %%
data.shape
# Out:
# (10015, 2353)

# %%
meta = pd.read_csv('/content/drive/MyDrive/skincancer_mnist_ham/HAM10000_metadata.csv')
meta.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
meta.shape
# Out:
# (10015, 7)

# %% [markdown]
# ### Summary Statistics

# %%
data.describe()
# Out:
#           pixel0000     pixel0001  ...     pixel2351         label
# count  10015.000000  10015.000000  ...  10015.000000  10015.000000
# mean     181.056415    131.728407  ...    133.144483      3.720919
# std       59.746698     45.043473  ...     49.060028      1.347499
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%      158.000000    117.000000  ...    115.000000      4.000000
# 50%      198.000000    141.000000  ...    142.000000      4.000000
# 75%      224.000000    159.000000  ...    163.000000      4.000000
# max      255.000000    246.000000  ...    254.000000      6.000000
#
# [8 rows x 2353 columns]

# %%
meta.describe()
# Out:
#                age
# count  9958.000000
# mean     51.863828
# std      16.968614
# min       0.000000
# 25%      40.000000
# 50%      50.000000
# 75%      65.000000
# max      85.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB

# %% [markdown]
# ### Check for Missing Values

# %%
data.isnull().sum()
# Out:
# pixel0000    0
# pixel0001    0
# pixel0002    0
# pixel0003    0
# pixel0004    0
#             ..
# pixel2348    0
# pixel2349    0
# pixel2350    0
# pixel2351    0
# label        0
# Length: 2353, dtype: int64

# %%
meta.isnull().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64

# %% [markdown]
# ### Imputation of Missing Values

# %% [markdown]
# We will use the mean to impute the missing values.

# %%
meta['age'].fillna((meta['age'].mean()), inplace=True)

# %%
meta.isnull().sum()
# Out:
# lesion_id       0
# image_id        0
# dx              0
# dx_type         0
# age             0
# sex             0
# localization    0
# dtype: int64

# %% [markdown]
# ### Check for Duplicate Values

# %%
meta.duplicated().any()
# Out:
# False

# %% [markdown]
# ### Check Distribution

# %% [markdown]
# #### 'Data'

# %% [markdown]
# Labels

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='label', data = data)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# #### 'Meta'

# %% [markdown]
# Age

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='age', data = meta, color='teal')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# Sex

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='sex', data = meta)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# dx

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='dx', data = meta)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# dx_type

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='dx_type', data = meta)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# localization

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='localization', data = meta, color='teal')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);
