# %% [markdown]
# # Fair Face Data Analysis

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Load Data

# %%
train_data1=pd.read_csv("/content/drive/MyDrive/fairface_resampling/fairface_original_train.csv")

# %%
train_data=train_data1.copy()

# %%
test_data1=pd.read_csv("/content/drive/MyDrive/fairface_resampling/fairface_original_test.csv")

# %%
test_data=test_data1.copy()

# %%
train_data.head()
# Out:
#           file    age  gender        race  service_test
# 0  train/1.jpg  50-59    Male  East Asian          True
# 1  train/2.jpg  30-39  Female      Indian         False
# 2  train/3.jpg    3-9  Female       Black         False
# 3  train/4.jpg  20-29  Female      Indian          True
# 4  train/5.jpg  20-29  Female      Indian          True

# %%
test_data.head()
# Out:
#         file    age  gender             race  service_test
# 0  val/1.jpg    3-9    Male       East Asian         False
# 1  val/2.jpg  50-59  Female       East Asian          True
# 2  val/3.jpg  30-39    Male            White          True
# 3  val/4.jpg  20-29  Female  Latino_Hispanic          True
# 4  val/5.jpg  20-29    Male  Southeast Asian         False

# %% [markdown]
# ### Check Number of Rows and Columns

# %%
train_data.shape
# Out:
# (86744, 5)

# %%
test_data.shape
# Out:
# (10954, 5)

# %% [markdown]
# #### List of necessary images in the train dataset

# %% [markdown]
# Train

# %% [markdown]
# Create list of unnecessary age groups and filter them out.

# %%
filter_age=['0-2','3-9','10-19','more than 70']
train_age_keep = train_data[~train_data.age.isin(filter_age)]

# %%
train_age_keep.shape
# Out:
# (64599, 5)

# %%
train_age_keep.head()
# Out:
#           file    age  gender        race  service_test
# 0  train/1.jpg  50-59    Male  East Asian          True
# 1  train/2.jpg  30-39  Female      Indian         False
# 3  train/4.jpg  20-29  Female      Indian          True
# 4  train/5.jpg  20-29  Female      Indian          True
# 5  train/6.jpg  20-29    Male       White          True

# %% [markdown]
# ### Export to CSV

# %%
train_age_keep.to_csv('/content/drive/MyDrive/fairface_resampling/train_keep_age_final.csv')

# %% [markdown]
# Repeat this process for the test data.

# %% [markdown]
# Test

# %%
filter_age=['0-2','3-9','10-19','more than 70']
test_age_keep = test_data[~test_data.age.isin(filter_age)]

# %%
test_age_keep.shape
# Out:
# (8100, 5)

# %%
test_age_keep.head()
# Out:
#         file    age  gender             race  service_test
# 1  val/2.jpg  50-59  Female       East Asian          True
# 2  val/3.jpg  30-39    Male            White          True
# 3  val/4.jpg  20-29  Female  Latino_Hispanic          True
# 4  val/5.jpg  20-29    Male  Southeast Asian         False
# 5  val/6.jpg  30-39    Male  Latino_Hispanic         False

# %%
test_age_keep.to_csv('/content/drive/MyDrive/fairface_resampling/test_keep_age_final.csv')
