# %% [markdown]
# # Fitzpatrick Undersampling Train Data

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load Data

# %%
train_data1=pd.read_csv("/content/drive/MyDrive/fairface_resampling/fitzpatrick_categorization/fitz_type_train_final.csv")

# %%
train_data=train_data1.copy()

# %%
train_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...  service_test phototype
# 0           0             0  ...          True       III
# 1           7             7  ...         False         V
# 2          66            78  ...         False       III
# 3         686           748  ...         False    I & II
# 4        6877          7415  ...         False         V
#
# [5 rows x 9 columns]

# %%
train_data.shape
# Out:
# (61046, 9)

# %% [markdown]
# #### Undersampling

# %% [markdown]
# The objective is to balance the data on 'gender' and 'phototype'. Manual undersampling was done by removing samples from the majority classes so that they are exactly equal to the minority class.

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = train_data)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
train_data['phototype'].value_counts()
# Out:
# V         22676
# I & II    12613
# IV         9528
# III        8349
# VI         7880
# Name: phototype, dtype: int64

# %% [markdown]
# Taking an equal number of samples for phototype

# %%
equal_phototype =train_data.groupby('phototype').head(7880)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_phototype)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_phototype)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_phototype['gender'].value_counts()
# Out:
# Male      20423
# Female    18977
# Name: gender, dtype: int64

# %% [markdown]
# From equal ethnicities, take equal age groups

# %%
equal_gender =equal_phototype.groupby('gender').head(18977)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_gender)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_gender)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_gender['phototype'].value_counts()
# Out:
# V         7880
# I & II    7880
# IV        7767
# III       7300
# VI        7127
# Name: phototype, dtype: int64

# %% [markdown]
# From equal age groups take equal ethnicities

# %%
equal_phototype_2 =equal_gender.groupby('phototype').head(7127)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_phototype_2)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_phototype_2)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_phototype_2['gender'].value_counts()
# Out:
# Male      17849
# Female    17786
# Name: gender, dtype: int64

# %% [markdown]
# From second round of equal ethnicities, take equal ages

# %%
equal_gender_2 =equal_phototype_2.groupby('gender').head(17786)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_gender_2)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_gender_2)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_gender_2['phototype'].value_counts()
# Out:
# V         7127
# IV        7127
# I & II    7127
# VI        7101
# III       7090
# Name: phototype, dtype: int64

# %%
equal_phototype_3 =equal_gender_2.groupby('phototype').head(7090)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_phototype_3)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_phototype_3)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_phototype_3['gender'].value_counts()
# Out:
# Female    17727
# Male      17723
# Name: gender, dtype: int64

# %%
equal_gender_4 =equal_phototype_3.groupby('gender').head(17723)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_gender_4)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_gender_4)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_gender_4['phototype'].value_counts()
# Out:
# V         7090
# III       7090
# IV        7090
# I & II    7090
# VI        7086
# Name: phototype, dtype: int64

# %%
equal_phototype_4 =equal_gender_4.groupby('phototype').head(7086)

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='phototype', data = equal_phototype_4)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
plt.figure(figsize=(10,10))
chart=sns.countplot(x ='gender', data = equal_phototype_4)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
equal_gender_4['gender'].value_counts()
# Out:
# Male      17723
# Female    17723
# Name: gender, dtype: int64

# %%
equal_phototype_4.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...  service_test phototype
# 0           0             0  ...          True       III
# 1           7             7  ...         False         V
# 2          66            78  ...         False       III
# 3         686           748  ...         False    I & II
# 4        6877          7415  ...         False         V
#
# [5 rows x 9 columns]

# %% [markdown]
# Print out csv of images for final dataset

# %%
equal_phototype_4.to_csv('/content/drive/MyDrive/fairface_resampling/fitz_undersampled_train.csv')
